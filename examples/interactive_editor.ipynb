# %% [markdown]
# # URDF2DT interactive editor
# Run the cell below. Load a URDF, then Preview, Accept and Unlock next for each frame. Drag to orbit; scroll to zoom. Reference acceptance and global FK validation remain pending.

# %%
from pathlib import Path
from urdf2dt.ui.dh_editor import DHEditor
editor = DHEditor()
root = Path.cwd()
if not (root / 'robots').exists():
    root = root.parent
editor.path.value = str(root / 'robots/ur5/ur5_serial.urdf')
editor.display()
