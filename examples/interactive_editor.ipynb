# %% [markdown]
# # URDF2DT interactive editor
# Run the cell below. Load a URDF, then Preview, Accept and Unlock next for each frame. Run Validate FK, then choose a new Session folder and Save session. Load session restores an export and rechecks it. Reference acceptance remains pending; sampled PASS is not a continuous-space proof.

# %%
from pathlib import Path
from urdf2dt.app import launch_editor
editor = launch_editor()
root = Path.cwd()
if not (root / 'robots').exists():
    root = root.parent
editor.path.value = str(root / 'robots/ur5/ur5_serial.urdf')
